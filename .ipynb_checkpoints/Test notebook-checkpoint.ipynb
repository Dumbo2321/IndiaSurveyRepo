# %%
data.raw <- read.csv("all.csv")
summary(data.raw)
# Out:
#        X                 State
#  Min.   :  1.0   UP         : 70
#  1st Qu.:148.2   MP         : 45
#  Median :295.5   Bihar      : 37
#  Mean   :295.5   Maharashtra: 35
#  3rd Qu.:442.8   Rajasthan  : 32
#  Max.   :590.0   TN         : 30
#                  (Other)    :341
#                                         District      Persons
#  District North                             :  2   Min.   :  31394
#  District Adilabad (01), Andhra Pradesh (28):  1   1st Qu.: 812718
#  District Agra (15), Uttar Pradesh (09)     :  1   Median :1487712
#  District Ahmadabad (07), Gujarat (24)      :  1   Mean   :1732902
#  District Ahmadnagar (26), Maharashtra (27) :  1   3rd Qu.:2395986
#  District Aizawl (03), Mizoram (15)         :  1   Max.   :9610788
#  (Other)                                    :583
#      Males            Females        Growth..1991...2001.     Rural
#  Min.   :  15893   Min.   :  14783   17.59  :  3          -      :  9
# ...
